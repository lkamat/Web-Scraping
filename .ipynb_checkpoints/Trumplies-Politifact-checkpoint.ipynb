# %%
# Web scraping fact checking article on Donald Trump statemnts from Politifact article
import requests  
r = requests.get('http://www.politifact.com/personalities/donald-trump/statements/byruling/false/')
from bs4 import BeautifulSoup  
soup = BeautifulSoup(r.text, 'html.parser')  
results = soup.find_all('div', attrs={'class':'scoretable__item'})
print(len(results))

records = []  
for result in results:  
    fact = result.find('p', attrs={'class':'quote'}).text
    lie =  result.find('a', attrs={'class':'link'}).text
    url =  result.find('a')['href'] 
    date = result.find('span',attrs={'class':'article__meta'}).text
    records.append(( lie,fact, url, date))

df = pd.DataFrame(records, columns=['Date', 'Lie','Fact', 'Url'])  
df
#df.to_csv('trump_lies_wp.csv', index=False, encoding='utf-8')
# Out:
# 20
#                                                   lie  \
# 0   "You take Pulse nightclub. If you had one pers...
# 1   The immigration visa lottery "randomly hands o...
# 2   "We enacted the biggest tax cuts and reforms i...
# 3   Says "22 to 24 people" came into the United St...
# 4   "I authorized Zero access to White House (actu...
# 5   There is "substantial evidence of voter fraud....
# 6   The Senate seat won in a special election by a...
# 7   Said Dianne Feinstein said "there is no collus...
# 8   "We have signed more legislation than anybody....
# 9   "We essentially repealed Obamacare because we ...
# 10  Missouri is one of "13 states this year have s...
# 11  "Black homeownership just hit the highest leve...
# 12  "Hillary Clinton lied many times to the FBI."\r\n
# 13  Says the tax bill "is going to cost me a fortu...
# 14  Says the GOP plan he supports is "the biggest ...
# 15  Insurance companies "have made a fortune with ...
# 16  "We're the highest developed nation taxed in t...
# 17  The Obama administration "borrowed more than $...
# 18            "Bob Corker gave us the Iran Deal."\r\n
# 19  Says "No, I don't benefit, I don't benefit" fr...
#
#                                                  fact  \
# 0                                 Armed guard present
# 1   Must be vetted, meet education or work require...
# 2                Repeating claim doesn't make it true
# 3                            No backup for this claim
# 4                                      Access denied?
# 5                             Wrong before, wrong now
# 6                            It was actually 21 years
# 7         Feinstein said collusion is "open question"
# 8                             He ranks last, actually
# 9                                Wrong on both counts
# 10                                    Not on the list
# 11               It's fallen almost yearly since 2004
# 12                          Comey said she didn't lie
# 13                           He stands to gain. A lot
# 14                               May be as low as 8th
# 15      Except for the billions lost on the exchanges
# 16                                    A mental block?
# 17                        Little link between the two
# 18                                   Way off the mark
# 19                               Let's count the ways
#
#                                                   url  \
# 0   /personalities/donald-trump/statements/byrulin...
# 1   /personalities/donald-trump/statements/byrulin...
# 2   /personalities/donald-trump/statements/byrulin...
# 3   /personalities/donald-trump/statements/byrulin...
# 4   /personalities/donald-trump/statements/byrulin...
# 5   /personalities/donald-trump/statements/byrulin...
# 6   /personalities/donald-trump/statements/byrulin...
# 7   /personalities/donald-trump/statements/byrulin...
# 8   /personalities/donald-trump/statements/byrulin...
# 9   /personalities/donald-trump/statements/byrulin...
# 10  /personalities/donald-trump/statements/byrulin...
# 11  /personalities/donald-trump/statements/byrulin...
# 12  /personalities/donald-trump/statements/byrulin...
# 13  /personalities/donald-trump/statements/byrulin...
# 14  /personalities/donald-trump/statements/byrulin...
# 15  /personalities/donald-trump/statements/byrulin...
# 16  /personalities/donald-trump/statements/byrulin...
# 17  /personalities/donald-trump/statements/byrulin...
# 18  /personalities/donald-trump/statements/byrulin...
# 19  /personalities/donald-trump/statements/byrulin...
#
#                                  date
# 0        on Thursday, March 1st, 2018
# 1      on Tuesday, January 30th, 2018
# 2      on Tuesday, January 30th, 2018
# 3    on Wednesday, January 24th, 2018
# 4        on Friday, January 5th, 2018
# 5      on Thursday, January 4th, 2018
# 6     on Wednesday, January 3rd, 2018
# 7       on Tuesday, January 2nd, 2018
# 8      on Friday, December 29th, 2017
# 9    on Thursday, December 21st, 2017
# 10     on Friday, December 15th, 2017
# 11     on Monday, December 11th, 2017
# 12     on Tuesday, December 5th, 2017
# 13   on Thursday, November 30th, 2017
# 14    on Thursday, October 26th, 2017
# 15      on Monday, October 23rd, 2017
# 16   on Wednesday, October 18th, 2017
# 17    on Thursday, October 12th, 2017
# 18    on Thursday, October 12th, 2017
# 19  on Thursday, September 28th, 2017
